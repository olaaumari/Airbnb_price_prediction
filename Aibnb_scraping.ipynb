# %%
from bs4 import BeautifulSoup as bs
from bs4 import SoupStrainer
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

import time
import requests
import pandas as pd

# %%
page = "https://www.airbnb.fr/s/Nice--France/homes?adults=1&place_id=ChIJMS2FahDQzRIRcJqX_aUZCAQ&refinement_paths%5B%5D=%2Fhomes&tab_id=home_tab&query=Nice%2C%20France&flexible_trip_lengths%5B%5D=one_week&date_picker_type=flexible_dates&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=september&source=structured_search_input_header&search_type=filter_change&price_max=219&amenities%5B%5D=4&amenities%5B%5D=5&amenities%5B%5D=58&amenities%5B%5D=25&price_min=130"

# %%
liens_partiels = []
liens_pages = []
hrefs= []
links = []
    
for y in range(15) :
    liens_pages.append(page + f'&items_offset={y*20}&section_offset=3')
for z in liens_pages :
    selection = SoupStrainer("a")
    b = bs(requests.get(z).content, 'html.parser',parse_only=selection)
    href_tags = b.find_all('a',class_="lwm61be dir dir-ltr",href=True)
    hrefs.append(href_tags)
for w in hrefs : 
    for x in w :
        a = x['href']
        liens_partiels.append(a)
for i in liens_partiels :
    v = 'https://www.airbnb.fr'+i
    links.append(v)

# %%
links = ['https://www.airbnb.fr/rooms/16598341?adults=1&children=0&infants=0&check_in=2023-05-10&check_out=2023-05-17&previous_page_section_name=1000&federated_search_id=b7730d26-d774-47b6-b6aa-44ba22fd8cfd',
 'https://www.airbnb.fr/rooms/54100655?adults=1&children=0&infants=0&check_in=2023-05-11&check_out=2023-05-18&previous_page_section_name=1000&federated_search_id=b7730d26-d774-47b6-b6aa-44ba22fd8cfd',
 'https://www.airbnb.fr/rooms/24866711?adults=1&children=0&infants=0&check_in=2023-05-22&check_out=2023-05-29&previous_page_section_name=1000&federated_search_id=b7730d26-d774-47b6-b6aa-44ba22fd8cfd',
 'https://www.airbnb.fr/rooms/3635671?adults=1&children=0&infants=0&check_in=2022-09-30&check_out=2022-10-07&previous_page_section_name=1000&federated_search_id=b7730d26-d774-47b6-b6aa-44ba22fd8cfd',
 'https://www.airbnb.fr/rooms/588099783134293350?adults=1&children=0&infants=0&check_in=2022-09-05&check_out=2022-09-12&previous_page_section_name=1000&federated_search_id=b7730d26-d774-47b6-b6aa-44ba22fd8cfd',
 'https://www.airbnb.fr/rooms/51936443?adults=1&children=0&infants=0&check_in=2023-05-02&check_out=2023-05-09&previous_page_section_name=1000&federated_search_id=b7730d26-d774-47b6-b6aa-44ba22fd8cfd',
 'https://www.airbnb.fr/rooms/22215497?adults=1&children=0&infants=0&check_in=2023-05-26&check_out=2023-06-02&previous_page_section_name=1000&federated_search_id=b7730d26-d774-47b6-b6aa-44ba22fd8cfd',
 'https://www.airbnb.fr/rooms/596912570082997986?adults=1&children=0&infants=0&check_in=2022-09-01&check_out=2022-09-08&previous_page_section_name=1000&federated_search_id=b7730d26-d774-47b6-b6aa-44ba22fd8cfd',
 'https://www.airbnb.fr/rooms/44491926?adults=1&children=0&infants=0&check_in=2022-09-16&check_out=2022-09-23&previous_page_section_name=1000&federated_search_id=a32f90fa-7324-43de-a578-36a882df968e']

# %%
features_dict = {'title':[],'price':[],'superhost':[],'statut':[],'grade':[],'nb_comment':[],'voyageurs':[],'nb_chambres':[],'nb_lits':[],
                'nb_sdb':[],'city':[],'Cuisine':[],'Télévision':[],'Sèche-cheveux':[],'Chauffage':[],
                'Lave-vaisselle':[],'Eau chaude':[],'Draps':[],'Wifi':[],'Climatisation':[],
                'Caméras de surveillance extérieure et/ou dans les espaces communs':[],'Entrée privée':[],'Jacuzzi':[],'Barbecue':[],'Équipements de base':[],
                'Cintres':[],'Lave-linge':[],'Détecteur de fumée':[],'Four à micro-ondes':[], 
                'Réfrigérateur':[],'Cuisinière':[],'Cafetière':[],'Shampooing':[],'Détecteur de monoxyde de carbone':[],'Séjours longue durée autorisés':[],'Baignoire':[]
                ,'Fer à repasser':[],'TV avec abonnement standard au câble':[],'Lit pour bébé':[],'Lit parapluie':[],
                'Accès plage ou bord de mer':[],'Ascenseur':[],"Stationnement payant à l'extérieur de la propriété":[],'Arrivée autonome':[],
                'Logement de plain-pied':[],'Vue panoramique sur la ville':[],'Vue sur la piscine':[],
                'Vue sur la baie':[],'Vue sur le jardin':[],'Vue sur la plage':[],'Vue sur le parc':[],'Vue sur le port':[],
                'Vue sur la mer':[],'Vue sur la montagne':[],'Savon pour le corps':[],'Oreillers et couvertures supplémentaires':[],'Connexion Ethernet':[],
                'Extincteur':[],'Congélateur':[],'Four':[],'Coffre-fort':[],'fumeur':[],
                'Ustensiles de barbecue':[],'Patio ou balcon : privé(e)':[],'Jardin privé(e), Clôture intégrale':[],'Parking gratuit':[],'Piscine':[],'Jacuzzi privé(e)':[],
                'Salle de sport':[],'Animaux acceptés':[],'Dépôt de bagages autorisé':[],"Clés remises par l'hôte":[] ,'Équipements de cuisine de base':[],
                }


equipements = ['Cuisine','Télévision','Sèche-cheveux','Chauffage','Coffre-fort',
                'Lave-vaisselle','Eau chaude','Draps','Wifi','Climatisation',
                'Caméras de surveillance extérieure et/ou dans les espaces communs','Entrée privée','Jacuzzi','Barbecue','Équipements de base',
                'Cintres','Lave-linge','Détecteur de fumée','Four à micro-ondes', 'Arrivée autonome',
                'Réfrigérateur','Cuisinière','Cafetière','Shampooing','Détecteur de monoxyde de carbone','Séjours longue durée autorisés','Baignoire',
                'Fer à repasser','TV avec abonnement standard au câble','Lit pour bébé','Lit parapluie',
                'Accès plage ou bord de mer','Ascenseur',"Stationnement payant à l'extérieur de la propriété",
                'Logement de plain-pied','Vue panoramique sur la ville','Vue sur la piscine',
                'Vue sur la baie','Vue sur le jardin','Vue sur la plage','Vue sur le parc','Vue sur le port',
                'Vue sur la mer','Vue sur la montagne','Savon pour le corps','Oreillers et couvertures supplémentaires','Connexion Ethernet',
                'Extincteur','Congélateur','Four',
                'Ustensiles de barbecue','Patio ou balcon : privé(e)','Jardin privé(e), Clôture intégrale','Parking gratuit','Piscine','Jacuzzi privé(e)',
                'Salle de sport','Animaux acceptés','Dépôt de bagages autorisé',"Clés remises par l'hôte",'Équipements de cuisine de base']



for link in links_150_180e :
    driver = webdriver.Chrome("chromedriver.exe")
    time.sleep(3)
    driver.get(link)
    time.sleep(10)
    driver.find_elements(By.XPATH,"/html/body/div[5]/div/div/div[1]/div/div/div[3]/section/div[2]/div[2]/button")[0].click()
                                    
    
    title_search = driver.find_elements(By.CLASS_NAME, value="_fecoyn4")
    for elem in title_search : 
        features_dict['title'].append(elem.text)

    prix_search = driver.find_elements(By.CLASS_NAME, value="_tyxjp1")
    for elem in prix_search :
        if elem.text != '' :
            features_dict['price'].append(elem.text)


    grade_search = driver.find_elements(By.CLASS_NAME, value="_17p6nbba")
    for elem in grade_search :
        features_dict['grade'].append(elem.text[0:4])


    try:
        superhost = driver.find_element(By.CLASS_NAME, value="_1mhorg9")
        features_dict['superhost'].append(superhost.text)
    except:
        features_dict['superhost'].append('NC')


    try :
        statut = driver.find_elements(By.XPATH, value='//*[@id="site-content"]/div/div[1]/div[6]/div/div/div/div[2]/div/section/div[1]/div[2]/div/ol/li[2]')
        for elem in statut :
            if 'Particulier' in elem.text :
                features_dict['statut'].append('Particulier')
            elif 'Professionnel' in elem.text :
                features_dict['statut'].append('Professionnel')
    except : pass
    
    
    
    commentaires_search = driver.find_elements(By.CLASS_NAME, value="_2qpirtt")
    for elem in commentaires_search : 
        if elem.text != '' :
            features_dict['nb_comment'].append(elem.text)

    li_search = driver.find_elements(By.TAG_NAME, value="li")
    #for elem in li_search : 
        #voy = li_search[0].text[0]
    features_dict['voyageurs'].append(li_search[0].text[0])
    features_dict['nb_chambres'].append(li_search[1].text[3])
    features_dict['nb_lits'].append(li_search[2].text[3])
    
    sdb = li_search[3].text[3]
    features_dict['nb_sdb'].append(sdb)

    city_search = driver.find_elements(By.CLASS_NAME, value="_9xiloll")
    for elem in city_search :
        features_dict['city'].append(elem.text[0:4])
        

    time.sleep(3)

    time.sleep(5)
    a = driver.find_elements(By.TAG_NAME, value='button')
    for elem in a :
        if 'équipements' in elem.text :
            elem.click()
            break

    time.sleep(5)
    equipements4 = driver.find_elements(By.CLASS_NAME, value="_11jhslp")
    equipements5 = driver.find_elements(By.CLASS_NAME,value='_gw4xx4')
    liste = []
    
    for e in equipements5 :
        liste.append(e.text)
     
    for e in equipements : 
        if e in liste :
            for k in liste :
                if e in k : 
                    if 'Indisponible' in k :
                                    if e in features_dict.keys():
                                        features_dict[e].append('Non disponible')
                                    else : pass
                    else : 
                        if e in features_dict.keys():
                            features_dict[e].append(e)
                        else : pass
        if e not in liste :
                features_dict[e].append('NC')
    
    
    
    driver.quit()


print(features_dict)
# Out:
# C:\Users\Oussama\AppData\Local\Temp\ipykernel_11928\1246903308.py:35: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# ...

# %%
df = pd.DataFrame.from_dict(features_dict, orient='index')
df = df.transpose()

# %%
df
# Out:
#                                                  title  price  superhost  \
# 0     Le Nomad: appartement central avec climatisation  164 €  Superhôte
# 1    N&J - DOLCE VITA MASTER - Hyper centre - Avenu...  146 €         NC
# 2        43 Clemenceau, lumineux 3 pièces avec balcons  131 €  Superhôte
# 3    Dernier étage balcon du marché 5mins Jean Medecin  146 €  Superhôte
# 4                                Sur les toits de Nice  144 €  Superhôte
# 5            Appartement centre ville terrasse +garage  140 €  Superhôte
# 6    Charming 2BR Seaview Flat with balcony in Old ...  129 €  Superhôte
# 7    N&J - GLORIA BEACH - Très proche mer - Immeubl...  151 €         NC
# 8                                           Le Magenta  145 €         NC
# 9           APPARTEMENT ELEGANT EN PLEIN COEUR DE NICE  138 €         NC
# 10             Stunning Apartment in the Port of Nice.  124 €         NC
# 11      Plage, Pde des Anglais et Place Masséna à 2 mn  122 €  Superhôte
# ...

# %%
df = df[:12]

# %%
df.head(30)
# Out:
#                                                 title  price  superhost  \
# 0    Le Nomad: appartement central avec climatisation  164 €  Superhôte
# 1   N&J - DOLCE VITA MASTER - Hyper centre - Avenu...  146 €         NC
# 2       43 Clemenceau, lumineux 3 pièces avec balcons  131 €  Superhôte
# 3   Dernier étage balcon du marché 5mins Jean Medecin  146 €  Superhôte
# 4                               Sur les toits de Nice  144 €  Superhôte
# 5           Appartement centre ville terrasse +garage  140 €  Superhôte
# 6   Charming 2BR Seaview Flat with balcony in Old ...  129 €  Superhôte
# 7   N&J - GLORIA BEACH - Très proche mer - Immeubl...  151 €         NC
# 8                                          Le Magenta  145 €         NC
# 9          APPARTEMENT ELEGANT EN PLEIN COEUR DE NICE  138 €         NC
# 10            Stunning Apartment in the Port of Nice.  124 €         NC
# 11     Plage, Pde des Anglais et Place Masséna à 2 mn  122 €  Superhôte
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = df[:300]

# %% [markdown]
# ## Premier df

# %%
df.to_csv('df_150e_180e_ouss.csv',sep='\t')

# %%
# Out:
#                                                 title  price  superhost  \
# 0            Appartement de charme - situation idéale  144 €         NC
# 1                Jacuzzi-quartier des musiciens -Loft  150 €  Superhôte
# 2       Villa Piscine Chauffée Jacuzzi Cagnes sur Mer  160 €  Superhôte
# 3         NICE - SPA - Vue mer - Jardin - 8 Personnes  134 €         NC
# 4   Rue de France, grand 2 pièces, 4 personnes vue...  110 €         NC
# 5   Jardin avec jacuzzi en plein centre ville à pr...  130 €         NC
# 6               3 pièces. Centre Nice. 50m de la voir  149 €         NC
# 7          Rooftop avec Jacuzzi et vue Mer / Sea View  171 €         NC
# 8                  Splendid flat- seaview- 4pers 66m2  114 €         NC
# 9   Appartement 6 personnes grande terrasse et jac...  180 €         NC
# 10    ⛱ Villa 2 pièces meublée avec piscine + jacuzzi  155 €         NC
# 11           HAVRE DE PAIX 🌴 bord de mer à Golfe Juan  162 €  Superhôte
# ...
